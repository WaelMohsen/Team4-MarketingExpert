# %%
from src.openai_client import OpenAIClient

# %%
client = OpenAIClient()

# %%
print(client._input_path)
# Out:
# /Users/marwa/Desktop/Marwa/NLP course/My project/prompt_engineering/campaign_platforms_data.json

# %%
messeges=client._creat_message()

# %%
print(messeges)
# Out:
# [{'role': 'system', 'content': 'You are a Digital Campaign Senior Analyst and Performance Strategist.\n\n# CONTEXT BACKGROUND\nYou support business stakeholders who are not marketers (executives, product owners, sales, operations). They need campaign results translated into clear business meaning and concrete next steps.\nYou analyze multi-platform campaign performance to understand:\n- How budget is being allocated and whether it is efficient\n- What business outcomes are being generated (leads, customers, revenue)\n- What’s working, what’s underperforming, and what to do next to hit the campaign target\n\n# PERSONA\n- Title: Digital Campaign Senior Analyst\n- Tone: business-formal, direct, simple\n- Language: plain English; avoid marketing terminologies; if unavoidable, define it in one short sentence.\n- Mindset: evidence-based, practical, transparent about uncertainty.\n\n# OPERATING RULES (MUST FOLLOW)\n1) Use ONLY the data provided in the input JSON. Do NOT invent budgets, conv
# ...

# %%
response= client._call_api(messeges)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 response= client._call_api(messeges)
#
# File ~/Desktop/Marwa/NLP course/My project/src/openai_client.py:51, in OpenAIClient._call_api(self, messages)
#      49 def _call_api(self, messages: list) -> str:
#      50     """Send messages to the model and return the raw response text."""
# ---> 51     response = self._client.chat.completions.create(
#      52         model       = self.model,
#      53         messages    = messages,
#      54         temperature = 0.2,   # low = consistent, factual, strict schema adherence
#      55     )
#      56     return response.choices[0].message.content
#
# File ~/anaconda3/lib/python3.10/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...
